# %% [markdown]
# <a href="https://colab.research.google.com/github/tthoraldson/space-art-generator/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Space Art Generation
# ## By Theresa Thoraldson

# %%
# COLAB ONLY
# tensorflow updates
# !pip show tensorflow
# !pip install --upgrade tensorflow

# install other libraries
# !pip install Pillow
# !pip install Image
# Out:
# Name: tensorflow
# Version: 1.12.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: opensource@google.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: keras-preprocessing, keras-applications, six, absl-py, protobuf, astor, gast, numpy, wheel, grpcio, termcolor, tensorboard
# Required-by: stable-baselines, magenta, fancyimpute
# Requirement already up-to-date: tensorflow in /usr/local/lib/python3.6/dist-packages (1.12.0)
# ...

# %%
import os
# from io import BytesIO
import tensorflow as tf
import PIL as Pillow
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
import numpy as np

# %%
# COLAB ONLY
# Check for GPU
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
def upload_files():
  from google.colab import files
  uploaded = files.upload()
  for k, v in uploaded.items():
    open(k, 'wb').write(v)
  return list(uploaded.keys())

dataset = upload_files()
# Out:
#      <input type="file" id="files-c81e6e12-6898-4e7d-bcd1-24fffdd62079" name="files[]" multiple disabled />
#      <output id="result-c81e6e12-6898-4e7d-bcd1-24fffdd62079">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 00001.jpg to 00001 (2).jpg

# %%
# Display sample image
sampleImage = Image.open(dataset[0], 'r')
plt.imshow(np.asarray(sampleImage))

# %%
minWidth = 1000
minHeight = 1000

for image in dataset:
  openImage = Image.open(image)
  currentImageWidth, currentImageHeight = openImage.size
  if currentImageWidth < minWidth:
    minWidth = currentImageWidth
  if currentImageHeight < minHeight:
    minHeight = currentImageHeight
    
print('Minimum width: ', minWidth)
print('Minimum height: ', minHeight)
  
for image in dataset:
  #CROP TO MIN WIDTH & HEIGHT
  continue
# Out:
# Minimum width:  500
# Minimum height:  673

# %% [markdown]
# - find widths & heights of all images
# - return minimum width and minimum height from images to ensure universal aspect ratio

# %% [markdown]
# # Parameters

# %%
learningRate = 0.001 #@param {type:"number"}
numberOfLayers = 5 #@param {type:"slider", min:1, max:20, step:1}
